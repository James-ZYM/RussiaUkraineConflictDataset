# %%
# Importing dependencies
import os
import pandas as pd
from langdetect import detect
import re

# %%
# Loading the csv-files and checking shape
data_csv = pd.read_csv(os.path.join('data','preprocessed_data_bigger_faster.csv'), index_col=0)
print(data_csv.shape)
data_csv
# Out:
# /tmp/ipykernel_25560/638223999.py:2: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_csv = pd.read_csv(os.path.join('data','preprocessed_data_bigger_faster.csv'), index_col=0)
# (11750592, 5)
#                                                   document sub_reddit  \
# 0        Ya pomniu etogo "diktatora" I ivo rech....day ...    ukraina
# 1        "Why Russians should take collective responsib...    ukraina
# 2        Reach out to russians and inform them about wa...    ukraina
# 3        March 23, 2022: UA Air Force destroyed 7 Russi...    ukraina
# 4        Zelenskyy addresses in English: “I ask you to ...    ukraina
# ...                                                    ...        ...
# 9547552  Yes but havent gained as much as in the first ...    ukraine
# 9547553  I saw on the news that it was some type of Wom...    ukraine
# 9547554      it is like saying that Ukraine invaded Russia    ukraine
# ...

# %%
# Loading the csv-files and checking shape
data_pkl = pd.read_pickle(os.path.join('data','preprocessed_data_bigger_faster.pkl'))
print(data_pkl.shape)
data_pkl
# Out:
# (8876701, 5)
#                                                   document sub_reddit  \
# 0        Ya pomniu etogo "diktatora" I ivo rech....day ...    ukraina
# 1        "Why Russians should take collective responsib...    ukraina
# 2        Reach out to russians and inform them about wa...    ukraina
# 3        March 23, 2022: UA Air Force destroyed 7 Russi...    ukraina
# 4        Zelenskyy addresses in English: “I ask you to ...    ukraina
# ...                                                    ...        ...
# 9547552  Yes but havent gained as much as in the first ...    ukraine
# 9547553  I saw on the news that it was some type of Wom...    ukraine
# 9547554      it is like saying that Ukraine invaded Russia    ukraine
# 9547555  If only the oligarchs supporting, funding and ...    ukraine
# 9547556  This is not as major as it sounds. They need t...    ukraine
#
#                date        type language
# 0        2022-03-23  submission       hr
# ...

# %%
print(data_csv.type.unique())
print(data_pkl.type.unique())
# Out:
# ['submission' 'comment' nan 'en' 'uk' 'ru' 'tr' 'no' 'bg' 'et' 'mk' 'pl'
#  'da' 'de' 'es' 'so' 'nl']
# ['submission' 'comment']
